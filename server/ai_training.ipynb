# %%
from ultralytics import YOLO, settings
import os

# %%
settings.reset()

# %%
current_directory = os.getcwd()

dataset_directory = os.path.join(current_directory, "AI\\dataset")
weights_directory = os.path.join(current_directory, "AI\\weights")
runs_directory = os.path.join(current_directory, "AI\\runs")

settings.update({"datasets_dir": f'{dataset_directory}', "weights_dir": f'{weights_directory}', "runs_dir": f'{runs_directory}'})

# %%
model = YOLO("yolov8n.pt")

# %%
model.train(data="data.yaml", epochs=10)
# Out:
# Ultralytics YOLOv8.2.16  Python-3.12.3 torch-2.3.0+cpu CPU (11th Gen Intel Core(TM) i7-11370H 3.30GHz)
# ...
